# %%
import requests
from fake_useragent import UserAgent

# %%
url = "https://civitai.com/api/v1/images"
params = {
    "sort": "Most Reactions",
    "period": "Day",
}
user_agent = UserAgent()

headers = {
    "User-Agent": user_agent.random,
}
response = requests.get(url, params=params, headers=headers)

# %%
images = response.json()['items']

# %%
images[0]
# Out:
# {'id': 42784829,
#  'url': 'https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/b6a8e8bf-7984-42a6-a7ea-517a7d289586/width=832/b6a8e8bf-7984-42a6-a7ea-517a7d289586.jpeg',
#  'hash': 'UBA^-In[0JEA.AIoMxjd00IA?a-=DhnnyEx-',
#  'width': 832,
#  'height': 1216,
#  'nsfwLevel': 'None',
#  'nsfw': False,
#  'browsingLevel': 1,
#  'createdAt': '2024-11-29T21:03:03.795Z',
#  'postId': 9738212,
#  'stats': {'cryCount': 34,
#   'laughCount': 45,
#   'likeCount': 379,
#   'dislikeCount': 0,
#   'heartCount': 119,
#   'commentCount': 0},
#  'meta': {'Size': '832x1216',
#   'seed': 1284673716,
#   'steps': 50,
#   'prompt': '((masterpiece), (best quality), (ultra-detailed), \nillustration, 3DMM,\n1woman, deep blue eyes, blue hair , very long hair, forehead, shirt, necktie, black footwear, high heels, sitting, looking at viewer, trees, sitting on log, night sky, stars, forest, futuristic,  hand prosthesis, scifi , lrg prosthesis, glossy, armor, cyborg,  perfect body, silver and blue glow,  sharp focus, mechanical joints, face focus, tears, crying,breeze, hair fluttering in the wind,From side-above, looking up,\n ,blue neon, prostheses, cyber prostheses,sits high above the ground, from side-up, head on profile, one leg raised at 45 degrees, head thrown back, lean on hands, tilted back )',
#   'sampler': 'Euler a',
#   'cfgScale': 7,
#   'clipSkip': 2,
#   'resources': [],
#   'Created Date': '2024-11-29T2049:42.6101451Z',
#   'negativePrompt': 'easynegative, verybadimagenegative_v1.3, negative_hand, worst quality, bad quality, artist name, jpeg artifacts, nsfw , bad hands, bad anatomy , bad anatomy,bad hands, missing fingers,extra digit,fewer digits,cropped,worst quality,low quality, bad-hands-5,badhandv4,',
#   'civitaiResources': [{'type': 'checkpoint',
#     'modelVersionId': 403131,
#     'modelVersionName': 'v3.1'},
#    {'type': 'lora',
#     'weight': 1,
#     'modelVersionId': 656719,
#     'modelVersionName': 'v1.0'}]},
#  'username': 'Norasi',
#  'baseModel': 'SDXL 1.0'}

# %%
img_url = images[0].get('url')
img_id = images[0].get('id')
prompt = images[0].get('meta').get('prompt')

# %%
get_img = requests.get(img_url, headers=headers)

get_img.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xe1\n\xd8Exif\x00\x00II*\x00\x08\x00\x00\x00\x01\x00i\x87\x04\x00\x01\x00\x00\x00\x1a\x00\x00\x00\x00\x00\x00\x00\x01\x00\x86\x92\x07\x00\xa4\n\x00\x00,\x00\x00\x00\x00\x00\x00\x00UNICODE\x00\x00(\x00(\x00m\x00a\x00s\x00t\x00e\x00r\x00p\x00i\x00e\x00c\x00e\x00)\x00,\x00 \x00(\x00b\x00e\x00s\x